# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
    pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)
# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 916us/sample - loss: 241.5572 - y1_output_loss: 113.6122 - y2_output_loss: 125.8116 - y1_output_root_mean_squared_error: 10.7066 - y2_output_root_mean_squared_error: 11.2662 - val_loss: 57.6883 - val_y1_output_loss: 18.7493 - val_y2_output_loss: 37.8993 - val_y1_output_root_mean_squared_error: 4.3483 - val_y2_output_root_mean_squared_error: 6.2274
# Epoch 2/500
# 614/614 [==============================] - 0s 144us/sample - loss: 36.7770 - y1_output_loss: 13.3582 - y2_output_loss: 23.0773 - y1_output_root_mean_squared_error: 3.6725 - y2_output_root_mean_squared_error: 4.8260 - val_loss: 25.3095 - val_y1_output_loss: 10.8474 - val_y2_output_loss: 13.9074 - val_y1_output_root_mean_squared_error: 3.3113 - val_y2_output_root_mean_squared_error: 3.7875
# Epoch 3/500
# 614/614 [==============================] - 0s 135us/sample - loss: 24.9211 - y1_output_loss: 9.9000 - y2_output_loss: 15.1467 - y1_output_root_mean_squared_error: 3.1452 - y2_output_root_mean_squared_error: 3.8767 - val_loss: 33.7086 - val_y1_output_loss: 11.7856 - val_y2_output_loss: 21.1061 - val_y1_output_root_mean_squared_error: 3.4655 - val_y2_output_root_mean_squared_error: 4.6582
# Epoch 4/500
# 614/614 [==============================] - 0s 134us/sample - loss: 23.2653 - y1_output_loss: 9.0324 - y2_output_loss: 14.0238 - y1_output_root_mean_squared_error: 3.0194 - y2_output_root_mean_squared_error: 3.7615 - val_loss: 21.8730 - val_y1_output_loss: 9.1455 - val_y2_output_loss: 12.0988 - val_y1_output_root_mean_squared_error: 3.0560 - val_y2_output_root_mean_squared_error: 3.5403
# Epoch 5/500
# 614/614 [==============================] - 0s 132us/sample - loss: 25.8501 - y1_output_loss: 9.1736 - y2_output_loss: 16.6679 - y1_output_root_mean_squared_error: 3.0208 - y2_output_root_mean_squared_error: 4.0896 - val_loss: 41.9830 - val_y1_output_loss: 12.9579 - val_y2_output_loss: 28.1280 - val_y1_output_root_mean_squared_error: 3.6342 - val_y2_output_root_mean_squared_error: 5.3643
# Epoch 6/500
# 614/614 [==============================] - 0s 133us/sample - loss: 22.5513 - y1_output_loss: 8.7628 - y2_output_loss: 14.1038 - y1_output_root_mean_squared_error: 2.9547 - y2_output_root_mean_squared_error: 3.7176 - val_loss: 32.5750 - val_y1_output_loss: 10.5576 - val_y2_output_loss: 21.3819 - val_y1_output_root_mean_squared_error: 3.2770 - val_y2_output_root_mean_squared_error: 4.6729
# Epoch 7/500
# 614/614 [==============================] - 0s 129us/sample - loss: 19.2332 - y1_output_loss: 7.6012 - y2_output_loss: 11.5179 - y1_output_root_mean_squared_error: 2.7693 - y2_output_root_mean_squared_error: 3.4006 - val_loss: 22.8385 - val_y1_output_loss: 8.9270 - val_y2_output_loss: 13.3397 - val_y1_output_root_mean_squared_error: 3.0089 - val_y2_output_root_mean_squared_error: 3.7128
# Epoch 8/500
# 614/614 [==============================] - 0s 131us/sample - loss: 22.5074 - y1_output_loss: 8.1160 - y2_output_loss: 14.3316 - y1_output_root_mean_squared_error: 2.8557 - y2_output_root_mean_squared_error: 3.7885 - val_loss: 20.9947 - val_y1_output_loss: 9.6964 - val_y2_output_loss: 10.9485 - val_y1_output_root_mean_squared_error: 3.1154 - val_y2_output_root_mean_squared_error: 3.3599
# Epoch 9/500
# 614/614 [==============================] - 0s 130us/sample - loss: 20.1747 - y1_output_loss: 7.5624 - y2_output_loss: 13.1060 - y1_output_root_mean_squared_error: 2.7274 - y2_output_root_mean_squared_error: 3.5688 - val_loss: 83.6603 - val_y1_output_loss: 23.0928 - val_y2_output_loss: 59.9627 - val_y1_output_root_mean_squared_error: 4.7900 - val_y2_output_root_mean_squared_error: 7.7920
# Epoch 10/500
# 614/614 [==============================] - 0s 133us/sample - loss: 22.4971 - y1_output_loss: 8.2676 - y2_output_loss: 14.0911 - y1_output_root_mean_squared_error: 2.8827 - y2_output_root_mean_squared_error: 3.7666 - val_loss: 44.6968 - val_y1_output_loss: 16.3592 - val_y2_output_loss: 28.1176 - val_y1_output_root_mean_squared_error: 4.0242 - val_y2_output_root_mean_squared_error: 5.3388
# Epoch 11/500
# 614/614 [==============================] - 0s 136us/sample - loss: 18.8346 - y1_output_loss: 6.9518 - y2_output_loss: 11.9456 - y1_output_root_mean_squared_error: 2.6239 - y2_output_root_mean_squared_error: 3.4568 - val_loss: 43.9656 - val_y1_output_loss: 16.9557 - val_y2_output_loss: 27.3008 - val_y1_output_root_mean_squared_error: 4.0671 - val_y2_output_root_mean_squared_error: 5.2368
# Epoch 12/500
# 614/614 [==============================] - 0s 133us/sample - loss: 16.9685 - y1_output_loss: 6.7793 - y2_output_loss: 10.2508 - y1_output_root_mean_squared_error: 2.5928 - y2_output_root_mean_squared_error: 3.2009 - val_loss: 23.8462 - val_y1_output_loss: 8.6467 - val_y2_output_loss: 14.8639 - val_y1_output_root_mean_squared_error: 2.9443 - val_y2_output_root_mean_squared_error: 3.8958
# Epoch 13/500
# 614/614 [==============================] - 0s 125us/sample - loss: 17.8748 - y1_output_loss: 6.7718 - y2_output_loss: 10.9549 - y1_output_root_mean_squared_error: 2.6142 - y2_output_root_mean_squared_error: 3.3227 - val_loss: 17.5149 - val_y1_output_loss: 7.2498 - val_y2_output_loss: 10.0269 - val_y1_output_root_mean_squared_error: 2.7092 - val_y2_output_root_mean_squared_error: 3.1898
# Epoch 14/500
# 614/614 [==============================] - 0s 137us/sample - loss: 15.7945 - y1_output_loss: 6.3797 - y2_output_loss: 9.6644 - y1_output_root_mean_squared_error: 2.5219 - y2_output_root_mean_squared_error: 3.0716 - val_loss: 30.3311 - val_y1_output_loss: 8.6199 - val_y2_output_loss: 21.5747 - val_y1_output_root_mean_squared_error: 2.9579 - val_y2_output_root_mean_squared_error: 4.6456
# Epoch 15/500
# 614/614 [==============================] - 0s 134us/sample - loss: 16.8792 - y1_output_loss: 6.3078 - y2_output_loss: 10.4162 - y1_output_root_mean_squared_error: 2.5228 - y2_output_root_mean_squared_error: 3.2426 - val_loss: 18.3414 - val_y1_output_loss: 7.0677 - val_y2_output_loss: 10.8150 - val_y1_output_root_mean_squared_error: 2.6736 - val_y2_output_root_mean_squared_error: 3.3457
# Epoch 16/500
# 614/614 [==============================] - 0s 129us/sample - loss: 15.8194 - y1_output_loss: 5.9176 - y2_output_loss: 9.7727 - y1_output_root_mean_squared_error: 2.4419 - y2_output_root_mean_squared_error: 3.1395 - val_loss: 16.1335 - val_y1_output_loss: 7.0949 - val_y2_output_loss: 8.6921 - val_y1_output_root_mean_squared_error: 2.6725 - val_y2_output_root_mean_squared_error: 2.9986
# Epoch 17/500
# 614/614 [==============================] - 0s 129us/sample - loss: 15.5275 - y1_output_loss: 6.0383 - y2_output_loss: 9.3852 - y1_output_root_mean_squared_error: 2.4681 - y2_output_root_mean_squared_error: 3.0718 - val_loss: 17.7795 - val_y1_output_loss: 7.6859 - val_y2_output_loss: 9.9194 - val_y1_output_root_mean_squared_error: 2.7539 - val_y2_output_root_mean_squared_error: 3.1930
# Epoch 18/500
# 614/614 [==============================] - 0s 124us/sample - loss: 14.4014 - y1_output_loss: 5.6974 - y2_output_loss: 8.5962 - y1_output_root_mean_squared_error: 2.3961 - y2_output_root_mean_squared_error: 2.9428 - val_loss: 16.2077 - val_y1_output_loss: 6.0169 - val_y2_output_loss: 9.7475 - val_y1_output_root_mean_squared_error: 2.4721 - val_y2_output_root_mean_squared_error: 3.1775
# Epoch 19/500
# 614/614 [==============================] - 0s 124us/sample - loss: 15.7811 - y1_output_loss: 5.7546 - y2_output_loss: 9.9053 - y1_output_root_mean_squared_error: 2.4056 - y2_output_root_mean_squared_error: 3.1614 - val_loss: 16.1617 - val_y1_output_loss: 6.5169 - val_y2_output_loss: 9.3264 - val_y1_output_root_mean_squared_error: 2.5548 - val_y2_output_root_mean_squared_error: 3.1040
# Epoch 20/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.0145 - y1_output_loss: 5.3269 - y2_output_loss: 8.9697 - y1_output_root_mean_squared_error: 2.3047 - y2_output_root_mean_squared_error: 2.9501 - val_loss: 41.7109 - val_y1_output_loss: 8.8593 - val_y2_output_loss: 33.4006 - val_y1_output_root_mean_squared_error: 2.9733 - val_y2_output_root_mean_squared_error: 5.7333
# Epoch 21/500
# 614/614 [==============================] - 0s 132us/sample - loss: 16.7254 - y1_output_loss: 6.1456 - y2_output_loss: 10.4669 - y1_output_root_mean_squared_error: 2.4897 - y2_output_root_mean_squared_error: 3.2445 - val_loss: 14.6104 - val_y1_output_loss: 5.6650 - val_y2_output_loss: 8.6142 - val_y1_output_root_mean_squared_error: 2.4021 - val_y2_output_root_mean_squared_error: 2.9733
# Epoch 22/500
# 614/614 [==============================] - 0s 127us/sample - loss: 15.0433 - y1_output_loss: 5.6124 - y2_output_loss: 9.2924 - y1_output_root_mean_squared_error: 2.3792 - y2_output_root_mean_squared_error: 3.0631 - val_loss: 13.7465 - val_y1_output_loss: 5.4614 - val_y2_output_loss: 8.0197 - val_y1_output_root_mean_squared_error: 2.3541 - val_y2_output_root_mean_squared_error: 2.8644
# Epoch 23/500
# 614/614 [==============================] - 0s 127us/sample - loss: 13.2482 - y1_output_loss: 5.1532 - y2_output_loss: 8.0548 - y1_output_root_mean_squared_error: 2.2704 - y2_output_root_mean_squared_error: 2.8449 - val_loss: 15.5206 - val_y1_output_loss: 5.9881 - val_y2_output_loss: 9.1453 - val_y1_output_root_mean_squared_error: 2.4660 - val_y2_output_root_mean_squared_error: 3.0724
# Epoch 24/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.6041 - y1_output_loss: 4.5847 - y2_output_loss: 6.9729 - y1_output_root_mean_squared_error: 2.1403 - y2_output_root_mean_squared_error: 2.6501 - val_loss: 16.5962 - val_y1_output_loss: 5.5311 - val_y2_output_loss: 10.5779 - val_y1_output_root_mean_squared_error: 2.3749 - val_y2_output_root_mean_squared_error: 3.3100
# Epoch 25/500
# 614/614 [==============================] - 0s 130us/sample - loss: 12.6386 - y1_output_loss: 4.8032 - y2_output_loss: 7.7260 - y1_output_root_mean_squared_error: 2.2008 - y2_output_root_mean_squared_error: 2.7920 - val_loss: 20.0688 - val_y1_output_loss: 8.2558 - val_y2_output_loss: 11.5378 - val_y1_output_root_mean_squared_error: 2.8596 - val_y2_output_root_mean_squared_error: 3.4484
# Epoch 26/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.1833 - y1_output_loss: 5.1727 - y2_output_loss: 8.9535 - y1_output_root_mean_squared_error: 2.2823 - y2_output_root_mean_squared_error: 2.9957 - val_loss: 18.1033 - val_y1_output_loss: 5.3787 - val_y2_output_loss: 12.1839 - val_y1_output_root_mean_squared_error: 2.3390 - val_y2_output_root_mean_squared_error: 3.5542
# Epoch 27/500
# 614/614 [==============================] - 0s 127us/sample - loss: 11.0665 - y1_output_loss: 4.1651 - y2_output_loss: 6.8530 - y1_output_root_mean_squared_error: 2.0503 - y2_output_root_mean_squared_error: 2.6197 - val_loss: 12.3836 - val_y1_output_loss: 4.8635 - val_y2_output_loss: 7.2316 - val_y1_output_root_mean_squared_error: 2.2231 - val_y2_output_root_mean_squared_error: 2.7279
# Epoch 28/500
# 614/614 [==============================] - 0s 120us/sample - loss: 13.3573 - y1_output_loss: 4.9086 - y2_output_loss: 8.4960 - y1_output_root_mean_squared_error: 2.2189 - y2_output_root_mean_squared_error: 2.9041 - val_loss: 28.6804 - val_y1_output_loss: 7.0268 - val_y2_output_loss: 21.4321 - val_y1_output_root_mean_squared_error: 2.6872 - val_y2_output_root_mean_squared_error: 4.6324
# Epoch 29/500
# 614/614 [==============================] - 0s 135us/sample - loss: 12.0459 - y1_output_loss: 4.4687 - y2_output_loss: 7.4696 - y1_output_root_mean_squared_error: 2.1241 - y2_output_root_mean_squared_error: 2.7449 - val_loss: 12.3405 - val_y1_output_loss: 4.9625 - val_y2_output_loss: 7.0789 - val_y1_output_root_mean_squared_error: 2.2354 - val_y2_output_root_mean_squared_error: 2.7099
# Epoch 30/500
# 614/614 [==============================] - 0s 128us/sample - loss: 10.1230 - y1_output_loss: 4.1238 - y2_output_loss: 6.0933 - y1_output_root_mean_squared_error: 2.0201 - y2_output_root_mean_squared_error: 2.4581 - val_loss: 38.0576 - val_y1_output_loss: 12.7813 - val_y2_output_loss: 24.5884 - val_y1_output_root_mean_squared_error: 3.5759 - val_y2_output_root_mean_squared_error: 5.0270
# Epoch 31/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.4837 - y1_output_loss: 3.9893 - y2_output_loss: 6.4607 - y1_output_root_mean_squared_error: 1.9981 - y2_output_root_mean_squared_error: 2.5478 - val_loss: 11.0067 - val_y1_output_loss: 4.1275 - val_y2_output_loss: 6.6070 - val_y1_output_root_mean_squared_error: 2.0522 - val_y2_output_root_mean_squared_error: 2.6067
# Epoch 32/500
# 614/614 [==============================] - 0s 130us/sample - loss: 9.6536 - y1_output_loss: 3.8262 - y2_output_loss: 5.8004 - y1_output_root_mean_squared_error: 1.9509 - y2_output_root_mean_squared_error: 2.4182 - val_loss: 11.2416 - val_y1_output_loss: 4.2547 - val_y2_output_loss: 6.6583 - val_y1_output_root_mean_squared_error: 2.0832 - val_y2_output_root_mean_squared_error: 2.6271
# Epoch 33/500
# 614/614 [==============================] - 0s 122us/sample - loss: 9.9955 - y1_output_loss: 3.6494 - y2_output_loss: 6.2825 - y1_output_root_mean_squared_error: 1.9134 - y2_output_root_mean_squared_error: 2.5168 - val_loss: 13.7706 - val_y1_output_loss: 6.0400 - val_y2_output_loss: 7.5123 - val_y1_output_root_mean_squared_error: 2.4448 - val_y2_output_root_mean_squared_error: 2.7917
# Epoch 34/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.1590 - y1_output_loss: 3.6937 - y2_output_loss: 6.4120 - y1_output_root_mean_squared_error: 1.9231 - y2_output_root_mean_squared_error: 2.5418 - val_loss: 10.6811 - val_y1_output_loss: 3.5762 - val_y2_output_loss: 6.8586 - val_y1_output_root_mean_squared_error: 1.9111 - val_y2_output_root_mean_squared_error: 2.6512
# Epoch 35/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.6065 - y1_output_loss: 3.5354 - y2_output_loss: 6.0529 - y1_output_root_mean_squared_error: 1.8833 - y2_output_root_mean_squared_error: 2.4616 - val_loss: 15.1409 - val_y1_output_loss: 4.2617 - val_y2_output_loss: 10.7948 - val_y1_output_root_mean_squared_error: 2.0832 - val_y2_output_root_mean_squared_error: 3.2865
# Epoch 36/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.2128 - y1_output_loss: 3.6775 - y2_output_loss: 5.4793 - y1_output_root_mean_squared_error: 1.9244 - y2_output_root_mean_squared_error: 2.3472 - val_loss: 16.0067 - val_y1_output_loss: 5.5618 - val_y2_output_loss: 10.0061 - val_y1_output_root_mean_squared_error: 2.3702 - val_y2_output_root_mean_squared_error: 3.2232
# Epoch 37/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.0711 - y1_output_loss: 3.8503 - y2_output_loss: 6.3830 - y1_output_root_mean_squared_error: 1.9623 - y2_output_root_mean_squared_error: 2.4941 - val_loss: 23.5356 - val_y1_output_loss: 4.0098 - val_y2_output_loss: 19.4627 - val_y1_output_root_mean_squared_error: 2.0247 - val_y2_output_root_mean_squared_error: 4.4086
# Epoch 38/500
# 614/614 [==============================] - 0s 122us/sample - loss: 8.7216 - y1_output_loss: 3.2291 - y2_output_loss: 5.4525 - y1_output_root_mean_squared_error: 1.7951 - y2_output_root_mean_squared_error: 2.3450 - val_loss: 8.9138 - val_y1_output_loss: 3.1042 - val_y2_output_loss: 5.6300 - val_y1_output_root_mean_squared_error: 1.7771 - val_y2_output_root_mean_squared_error: 2.3991
# Epoch 39/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.6778 - y1_output_loss: 2.9789 - y2_output_loss: 5.6288 - y1_output_root_mean_squared_error: 1.7327 - y2_output_root_mean_squared_error: 2.3823 - val_loss: 11.2542 - val_y1_output_loss: 3.6280 - val_y2_output_loss: 7.3127 - val_y1_output_root_mean_squared_error: 1.9161 - val_y2_output_root_mean_squared_error: 2.7537
# Epoch 40/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.8580 - y1_output_loss: 2.7730 - y2_output_loss: 5.0358 - y1_output_root_mean_squared_error: 1.6710 - y2_output_root_mean_squared_error: 2.2508 - val_loss: 17.9331 - val_y1_output_loss: 4.8698 - val_y2_output_loss: 12.5293 - val_y1_output_root_mean_squared_error: 2.2214 - val_y2_output_root_mean_squared_error: 3.6053
# Epoch 41/500
# 614/614 [==============================] - 0s 132us/sample - loss: 10.8343 - y1_output_loss: 3.3262 - y2_output_loss: 7.6379 - y1_output_root_mean_squared_error: 1.8021 - y2_output_root_mean_squared_error: 2.7544 - val_loss: 10.4075 - val_y1_output_loss: 3.3037 - val_y2_output_loss: 6.8704 - val_y1_output_root_mean_squared_error: 1.8444 - val_y2_output_root_mean_squared_error: 2.6468
# Epoch 42/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.3423 - y1_output_loss: 2.9472 - y2_output_loss: 5.3228 - y1_output_root_mean_squared_error: 1.7246 - y2_output_root_mean_squared_error: 2.3169 - val_loss: 10.8991 - val_y1_output_loss: 3.4234 - val_y2_output_loss: 7.1939 - val_y1_output_root_mean_squared_error: 1.8577 - val_y2_output_root_mean_squared_error: 2.7291
# Epoch 43/500
# 614/614 [==============================] - 0s 121us/sample - loss: 9.3100 - y1_output_loss: 3.1765 - y2_output_loss: 6.1127 - y1_output_root_mean_squared_error: 1.7745 - y2_output_root_mean_squared_error: 2.4822 - val_loss: 11.3797 - val_y1_output_loss: 3.1784 - val_y2_output_loss: 8.0366 - val_y1_output_root_mean_squared_error: 1.8086 - val_y2_output_root_mean_squared_error: 2.8476
# Epoch 44/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.5232 - y1_output_loss: 2.6125 - y2_output_loss: 4.8598 - y1_output_root_mean_squared_error: 1.6203 - y2_output_root_mean_squared_error: 2.2131 - val_loss: 8.0834 - val_y1_output_loss: 2.6227 - val_y2_output_loss: 5.2688 - val_y1_output_root_mean_squared_error: 1.6385 - val_y2_output_root_mean_squared_error: 2.3235
# Epoch 45/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.4387 - y1_output_loss: 2.7654 - y2_output_loss: 5.6596 - y1_output_root_mean_squared_error: 1.6621 - y2_output_root_mean_squared_error: 2.3824 - val_loss: 19.8304 - val_y1_output_loss: 6.7775 - val_y2_output_loss: 12.5263 - val_y1_output_root_mean_squared_error: 2.6493 - val_y2_output_root_mean_squared_error: 3.5793
# Epoch 46/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.0204 - y1_output_loss: 2.7288 - y2_output_loss: 5.2960 - y1_output_root_mean_squared_error: 1.6544 - y2_output_root_mean_squared_error: 2.2986 - val_loss: 9.3605 - val_y1_output_loss: 3.5663 - val_y2_output_loss: 5.7067 - val_y1_output_root_mean_squared_error: 1.9155 - val_y2_output_root_mean_squared_error: 2.3857
# Epoch 47/500
# 614/614 [==============================] - 0s 138us/sample - loss: 8.4253 - y1_output_loss: 2.8123 - y2_output_loss: 5.7016 - y1_output_root_mean_squared_error: 1.6559 - y2_output_root_mean_squared_error: 2.3840 - val_loss: 11.4876 - val_y1_output_loss: 3.0358 - val_y2_output_loss: 8.3223 - val_y1_output_root_mean_squared_error: 1.7679 - val_y2_output_root_mean_squared_error: 2.8917
# Epoch 48/500
# 614/614 [==============================] - 0s 122us/sample - loss: 6.9909 - y1_output_loss: 2.4776 - y2_output_loss: 4.5379 - y1_output_root_mean_squared_error: 1.5728 - y2_output_root_mean_squared_error: 2.1253 - val_loss: 16.3228 - val_y1_output_loss: 3.9059 - val_y2_output_loss: 12.2453 - val_y1_output_root_mean_squared_error: 2.0113 - val_y2_output_root_mean_squared_error: 3.5039
# Epoch 49/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.6270 - y1_output_loss: 2.4960 - y2_output_loss: 5.1246 - y1_output_root_mean_squared_error: 1.5831 - y2_output_root_mean_squared_error: 2.2629 - val_loss: 8.7226 - val_y1_output_loss: 1.9631 - val_y2_output_loss: 6.8085 - val_y1_output_root_mean_squared_error: 1.4230 - val_y2_output_root_mean_squared_error: 2.5880
# Epoch 50/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.7123 - y1_output_loss: 2.8061 - y2_output_loss: 5.8505 - y1_output_root_mean_squared_error: 1.6806 - y2_output_root_mean_squared_error: 2.4265 - val_loss: 8.5732 - val_y1_output_loss: 2.3814 - val_y2_output_loss: 6.1983 - val_y1_output_root_mean_squared_error: 1.5699 - val_y2_output_root_mean_squared_error: 2.4716
# Epoch 51/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.7554 - y1_output_loss: 2.1912 - y2_output_loss: 4.5109 - y1_output_root_mean_squared_error: 1.4847 - y2_output_root_mean_squared_error: 2.1333 - val_loss: 7.4439 - val_y1_output_loss: 2.2120 - val_y2_output_loss: 5.1119 - val_y1_output_root_mean_squared_error: 1.4972 - val_y2_output_root_mean_squared_error: 2.2809
# Epoch 52/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.8635 - y1_output_loss: 2.3733 - y2_output_loss: 4.7546 - y1_output_root_mean_squared_error: 1.5193 - y2_output_root_mean_squared_error: 2.1343 - val_loss: 107.8190 - val_y1_output_loss: 33.8936 - val_y2_output_loss: 71.0961 - val_y1_output_root_mean_squared_error: 5.8830 - val_y2_output_root_mean_squared_error: 8.5562
# Epoch 53/500
# 614/614 [==============================] - 0s 126us/sample - loss: 8.4694 - y1_output_loss: 2.7384 - y2_output_loss: 5.6512 - y1_output_root_mean_squared_error: 1.6623 - y2_output_root_mean_squared_error: 2.3887 - val_loss: 6.6734 - val_y1_output_loss: 1.8851 - val_y2_output_loss: 4.6734 - val_y1_output_root_mean_squared_error: 1.3786 - val_y2_output_root_mean_squared_error: 2.1847
# Epoch 54/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.6781 - y1_output_loss: 2.2032 - y2_output_loss: 4.4588 - y1_output_root_mean_squared_error: 1.4771 - y2_output_root_mean_squared_error: 2.1204 - val_loss: 8.5714 - val_y1_output_loss: 2.6580 - val_y2_output_loss: 5.7444 - val_y1_output_root_mean_squared_error: 1.6494 - val_y2_output_root_mean_squared_error: 2.4189
# Epoch 55/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.6211 - y1_output_loss: 2.1823 - y2_output_loss: 4.4005 - y1_output_root_mean_squared_error: 1.4826 - y2_output_root_mean_squared_error: 2.1031 - val_loss: 8.7637 - val_y1_output_loss: 2.0657 - val_y2_output_loss: 6.7015 - val_y1_output_root_mean_squared_error: 1.4607 - val_y2_output_root_mean_squared_error: 2.5749
# Epoch 56/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.8869 - y1_output_loss: 1.8919 - y2_output_loss: 3.9426 - y1_output_root_mean_squared_error: 1.3812 - y2_output_root_mean_squared_error: 1.9948 - val_loss: 7.0845 - val_y1_output_loss: 2.2582 - val_y2_output_loss: 4.7785 - val_y1_output_root_mean_squared_error: 1.4933 - val_y2_output_root_mean_squared_error: 2.2033
# Epoch 57/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.1972 - y1_output_loss: 1.8758 - y2_output_loss: 4.2649 - y1_output_root_mean_squared_error: 1.3754 - y2_output_root_mean_squared_error: 2.0749 - val_loss: 11.7545 - val_y1_output_loss: 2.6386 - val_y2_output_loss: 9.0263 - val_y1_output_root_mean_squared_error: 1.6498 - val_y2_output_root_mean_squared_error: 3.0054
# Epoch 58/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.9378 - y1_output_loss: 2.1316 - y2_output_loss: 4.8423 - y1_output_root_mean_squared_error: 1.4635 - y2_output_root_mean_squared_error: 2.1899 - val_loss: 6.5469 - val_y1_output_loss: 1.9330 - val_y2_output_loss: 4.5621 - val_y1_output_root_mean_squared_error: 1.4037 - val_y2_output_root_mean_squared_error: 2.1393
# Epoch 59/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.1419 - y1_output_loss: 1.9713 - y2_output_loss: 4.1152 - y1_output_root_mean_squared_error: 1.4105 - y2_output_root_mean_squared_error: 2.0378 - val_loss: 6.8820 - val_y1_output_loss: 1.9805 - val_y2_output_loss: 4.8253 - val_y1_output_root_mean_squared_error: 1.3998 - val_y2_output_root_mean_squared_error: 2.2187
# Epoch 60/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.6690 - y1_output_loss: 1.8555 - y2_output_loss: 3.8158 - y1_output_root_mean_squared_error: 1.3566 - y2_output_root_mean_squared_error: 1.9567 - val_loss: 8.7505 - val_y1_output_loss: 2.3300 - val_y2_output_loss: 6.3740 - val_y1_output_root_mean_squared_error: 1.5527 - val_y2_output_root_mean_squared_error: 2.5178
# Epoch 61/500
# 614/614 [==============================] - 0s 135us/sample - loss: 6.1898 - y1_output_loss: 1.8479 - y2_output_loss: 4.2944 - y1_output_root_mean_squared_error: 1.3649 - y2_output_root_mean_squared_error: 2.0801 - val_loss: 12.2287 - val_y1_output_loss: 3.1971 - val_y2_output_loss: 8.7790 - val_y1_output_root_mean_squared_error: 1.7831 - val_y2_output_root_mean_squared_error: 3.0082
# Epoch 62/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.8099 - y1_output_loss: 1.8768 - y2_output_loss: 4.0536 - y1_output_root_mean_squared_error: 1.3671 - y2_output_root_mean_squared_error: 1.9852 - val_loss: 8.3070 - val_y1_output_loss: 2.7329 - val_y2_output_loss: 5.5061 - val_y1_output_root_mean_squared_error: 1.6787 - val_y2_output_root_mean_squared_error: 2.3429
# Epoch 63/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.0947 - y1_output_loss: 2.4130 - y2_output_loss: 4.6288 - y1_output_root_mean_squared_error: 1.5575 - y2_output_root_mean_squared_error: 2.1608 - val_loss: 7.8204 - val_y1_output_loss: 2.4467 - val_y2_output_loss: 5.3272 - val_y1_output_root_mean_squared_error: 1.5492 - val_y2_output_root_mean_squared_error: 2.3282
# Epoch 64/500
# 614/614 [==============================] - 0s 122us/sample - loss: 5.6772 - y1_output_loss: 1.7736 - y2_output_loss: 3.9277 - y1_output_root_mean_squared_error: 1.3306 - y2_output_root_mean_squared_error: 1.9765 - val_loss: 7.0348 - val_y1_output_loss: 1.6415 - val_y2_output_loss: 5.2784 - val_y1_output_root_mean_squared_error: 1.2971 - val_y2_output_root_mean_squared_error: 2.3135
# Epoch 65/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.5034 - y1_output_loss: 1.5586 - y2_output_loss: 3.9398 - y1_output_root_mean_squared_error: 1.2513 - y2_output_root_mean_squared_error: 1.9844 - val_loss: 6.3410 - val_y1_output_loss: 1.5318 - val_y2_output_loss: 4.7820 - val_y1_output_root_mean_squared_error: 1.2479 - val_y2_output_root_mean_squared_error: 2.1872
# Epoch 66/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.3479 - y1_output_loss: 1.7962 - y2_output_loss: 4.5316 - y1_output_root_mean_squared_error: 1.3341 - y2_output_root_mean_squared_error: 2.1373 - val_loss: 6.7790 - val_y1_output_loss: 1.5706 - val_y2_output_loss: 5.0502 - val_y1_output_root_mean_squared_error: 1.2647 - val_y2_output_root_mean_squared_error: 2.2759
# Epoch 67/500
# 614/614 [==============================] - 0s 129us/sample - loss: 13.2286 - y1_output_loss: 4.1839 - y2_output_loss: 9.0548 - y1_output_root_mean_squared_error: 2.0498 - y2_output_root_mean_squared_error: 3.0045 - val_loss: 11.2867 - val_y1_output_loss: 1.7784 - val_y2_output_loss: 9.8021 - val_y1_output_root_mean_squared_error: 1.3522 - val_y2_output_root_mean_squared_error: 3.0754
# Epoch 68/500
# 614/614 [==============================] - 0s 123us/sample - loss: 5.3446 - y1_output_loss: 1.7661 - y2_output_loss: 3.5377 - y1_output_root_mean_squared_error: 1.3338 - y2_output_root_mean_squared_error: 1.8883 - val_loss: 7.0906 - val_y1_output_loss: 1.7827 - val_y2_output_loss: 5.2042 - val_y1_output_root_mean_squared_error: 1.3394 - val_y2_output_root_mean_squared_error: 2.3014
# Epoch 69/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.7519 - y1_output_loss: 1.5385 - y2_output_loss: 3.2008 - y1_output_root_mean_squared_error: 1.2410 - y2_output_root_mean_squared_error: 1.7922 - val_loss: 7.6985 - val_y1_output_loss: 1.5315 - val_y2_output_loss: 5.9955 - val_y1_output_root_mean_squared_error: 1.2357 - val_y2_output_root_mean_squared_error: 2.4842
# Epoch 70/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.6992 - y1_output_loss: 2.4011 - y2_output_loss: 5.3020 - y1_output_root_mean_squared_error: 1.5512 - y2_output_root_mean_squared_error: 2.3006 - val_loss: 10.0314 - val_y1_output_loss: 2.0149 - val_y2_output_loss: 7.9463 - val_y1_output_root_mean_squared_error: 1.4337 - val_y2_output_root_mean_squared_error: 2.8242
# Epoch 71/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.7942 - y1_output_loss: 1.9154 - y2_output_loss: 3.8506 - y1_output_root_mean_squared_error: 1.3878 - y2_output_root_mean_squared_error: 1.9668 - val_loss: 10.1284 - val_y1_output_loss: 3.0327 - val_y2_output_loss: 6.9435 - val_y1_output_root_mean_squared_error: 1.7214 - val_y2_output_root_mean_squared_error: 2.6768
# Epoch 72/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.1987 - y1_output_loss: 1.5060 - y2_output_loss: 3.6818 - y1_output_root_mean_squared_error: 1.2301 - y2_output_root_mean_squared_error: 1.9198 - val_loss: 7.5180 - val_y1_output_loss: 1.4934 - val_y2_output_loss: 6.0349 - val_y1_output_root_mean_squared_error: 1.2394 - val_y2_output_root_mean_squared_error: 2.4458
# Epoch 73/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.8258 - y1_output_loss: 1.5802 - y2_output_loss: 4.3269 - y1_output_root_mean_squared_error: 1.2453 - y2_output_root_mean_squared_error: 2.0676 - val_loss: 17.3964 - val_y1_output_loss: 2.7527 - val_y2_output_loss: 14.3875 - val_y1_output_root_mean_squared_error: 1.6643 - val_y2_output_root_mean_squared_error: 3.8245
# Epoch 74/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.9047 - y1_output_loss: 1.4086 - y2_output_loss: 3.4749 - y1_output_root_mean_squared_error: 1.1858 - y2_output_root_mean_squared_error: 1.8704 - val_loss: 5.3833 - val_y1_output_loss: 1.3299 - val_y2_output_loss: 3.9458 - val_y1_output_root_mean_squared_error: 1.1722 - val_y2_output_root_mean_squared_error: 2.0023
# Epoch 75/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.6956 - y1_output_loss: 1.3882 - y2_output_loss: 3.2770 - y1_output_root_mean_squared_error: 1.1790 - y2_output_root_mean_squared_error: 1.8181 - val_loss: 5.3161 - val_y1_output_loss: 1.4883 - val_y2_output_loss: 3.7741 - val_y1_output_root_mean_squared_error: 1.2411 - val_y2_output_root_mean_squared_error: 1.9432
# Epoch 76/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.8865 - y1_output_loss: 1.3487 - y2_output_loss: 3.5364 - y1_output_root_mean_squared_error: 1.1636 - y2_output_root_mean_squared_error: 1.8795 - val_loss: 7.6203 - val_y1_output_loss: 1.7070 - val_y2_output_loss: 5.9692 - val_y1_output_root_mean_squared_error: 1.3292 - val_y2_output_root_mean_squared_error: 2.4194
# Epoch 77/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.0804 - y1_output_loss: 1.1682 - y2_output_loss: 2.9780 - y1_output_root_mean_squared_error: 1.0856 - y2_output_root_mean_squared_error: 1.7035 - val_loss: 12.8884 - val_y1_output_loss: 1.6765 - val_y2_output_loss: 11.7039 - val_y1_output_root_mean_squared_error: 1.3064 - val_y2_output_root_mean_squared_error: 3.3439
# Epoch 78/500
# 614/614 [==============================] - 0s 121us/sample - loss: 5.0080 - y1_output_loss: 1.4559 - y2_output_loss: 3.5206 - y1_output_root_mean_squared_error: 1.2101 - y2_output_root_mean_squared_error: 1.8825 - val_loss: 5.6475 - val_y1_output_loss: 1.3600 - val_y2_output_loss: 4.2415 - val_y1_output_root_mean_squared_error: 1.1811 - val_y2_output_root_mean_squared_error: 2.0622
# Epoch 79/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.5187 - y1_output_loss: 1.3105 - y2_output_loss: 3.2110 - y1_output_root_mean_squared_error: 1.1436 - y2_output_root_mean_squared_error: 1.7919 - val_loss: 10.9803 - val_y1_output_loss: 2.4271 - val_y2_output_loss: 8.6100 - val_y1_output_root_mean_squared_error: 1.5844 - val_y2_output_root_mean_squared_error: 2.9103
# Epoch 80/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5540 - y1_output_loss: 1.3999 - y2_output_loss: 3.1590 - y1_output_root_mean_squared_error: 1.1838 - y2_output_root_mean_squared_error: 1.7755 - val_loss: 9.1721 - val_y1_output_loss: 1.8211 - val_y2_output_loss: 7.1173 - val_y1_output_root_mean_squared_error: 1.3455 - val_y2_output_root_mean_squared_error: 2.7132
# Epoch 81/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.5536 - y1_output_loss: 1.5227 - y2_output_loss: 4.0122 - y1_output_root_mean_squared_error: 1.2287 - y2_output_root_mean_squared_error: 2.0109 - val_loss: 4.5652 - val_y1_output_loss: 0.9681 - val_y2_output_loss: 3.6409 - val_y1_output_root_mean_squared_error: 1.0019 - val_y2_output_root_mean_squared_error: 1.8872
# Epoch 82/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.3068 - y1_output_loss: 1.2297 - y2_output_loss: 3.0791 - y1_output_root_mean_squared_error: 1.1114 - y2_output_root_mean_squared_error: 1.7526 - val_loss: 6.1992 - val_y1_output_loss: 1.3311 - val_y2_output_loss: 4.8830 - val_y1_output_root_mean_squared_error: 1.1703 - val_y2_output_root_mean_squared_error: 2.1976
# Epoch 83/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.7551 - y1_output_loss: 1.1620 - y2_output_loss: 2.6022 - y1_output_root_mean_squared_error: 1.0770 - y2_output_root_mean_squared_error: 1.6110 - val_loss: 8.8863 - val_y1_output_loss: 1.9631 - val_y2_output_loss: 6.7940 - val_y1_output_root_mean_squared_error: 1.3820 - val_y2_output_root_mean_squared_error: 2.6413
# Epoch 84/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0997 - y1_output_loss: 1.2254 - y2_output_loss: 2.8405 - y1_output_root_mean_squared_error: 1.1116 - y2_output_root_mean_squared_error: 1.6923 - val_loss: 6.1038 - val_y1_output_loss: 1.2313 - val_y2_output_loss: 4.7327 - val_y1_output_root_mean_squared_error: 1.1245 - val_y2_output_root_mean_squared_error: 2.1999
# Epoch 85/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.4258 - y1_output_loss: 0.9667 - y2_output_loss: 2.4397 - y1_output_root_mean_squared_error: 0.9865 - y2_output_root_mean_squared_error: 1.5661 - val_loss: 5.8445 - val_y1_output_loss: 1.8196 - val_y2_output_loss: 3.9784 - val_y1_output_root_mean_squared_error: 1.3438 - val_y2_output_root_mean_squared_error: 2.0097
# Epoch 86/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.7871 - y1_output_loss: 1.0389 - y2_output_loss: 2.7688 - y1_output_root_mean_squared_error: 1.0147 - y2_output_root_mean_squared_error: 1.6606 - val_loss: 9.3860 - val_y1_output_loss: 3.4812 - val_y2_output_loss: 5.7087 - val_y1_output_root_mean_squared_error: 1.8980 - val_y2_output_root_mean_squared_error: 2.4049
# Epoch 87/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.5880 - y1_output_loss: 1.0420 - y2_output_loss: 2.6033 - y1_output_root_mean_squared_error: 1.0191 - y2_output_root_mean_squared_error: 1.5967 - val_loss: 10.0772 - val_y1_output_loss: 0.9358 - val_y2_output_loss: 9.3106 - val_y1_output_root_mean_squared_error: 0.9833 - val_y2_output_root_mean_squared_error: 3.0183
# Epoch 88/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3367 - y1_output_loss: 0.8669 - y2_output_loss: 2.4977 - y1_output_root_mean_squared_error: 0.9190 - y2_output_root_mean_squared_error: 1.5787 - val_loss: 4.3727 - val_y1_output_loss: 0.9954 - val_y2_output_loss: 3.4295 - val_y1_output_root_mean_squared_error: 1.0142 - val_y2_output_root_mean_squared_error: 1.8287
# Epoch 89/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.8874 - y1_output_loss: 1.0830 - y2_output_loss: 2.7814 - y1_output_root_mean_squared_error: 1.0429 - y2_output_root_mean_squared_error: 1.6733 - val_loss: 4.9073 - val_y1_output_loss: 0.8962 - val_y2_output_loss: 3.9253 - val_y1_output_root_mean_squared_error: 0.9503 - val_y2_output_root_mean_squared_error: 2.0011
# Epoch 90/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.6109 - y1_output_loss: 0.8715 - y2_output_loss: 2.7414 - y1_output_root_mean_squared_error: 0.9350 - y2_output_root_mean_squared_error: 1.6543 - val_loss: 7.6800 - val_y1_output_loss: 1.4913 - val_y2_output_loss: 6.2946 - val_y1_output_root_mean_squared_error: 1.2389 - val_y2_output_root_mean_squared_error: 2.4790
# Epoch 91/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.7168 - y1_output_loss: 0.9056 - y2_output_loss: 2.8179 - y1_output_root_mean_squared_error: 0.9523 - y2_output_root_mean_squared_error: 1.6763 - val_loss: 13.8580 - val_y1_output_loss: 2.4528 - val_y2_output_loss: 11.2908 - val_y1_output_root_mean_squared_error: 1.5946 - val_y2_output_root_mean_squared_error: 3.3638
# Epoch 92/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.5954 - y1_output_loss: 1.7558 - y2_output_loss: 3.8193 - y1_output_root_mean_squared_error: 1.3309 - y2_output_root_mean_squared_error: 1.9555 - val_loss: 4.9798 - val_y1_output_loss: 0.6966 - val_y2_output_loss: 4.4187 - val_y1_output_root_mean_squared_error: 0.8460 - val_y2_output_root_mean_squared_error: 2.0650
# Epoch 93/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.9687 - y1_output_loss: 0.9736 - y2_output_loss: 2.9653 - y1_output_root_mean_squared_error: 0.9898 - y2_output_root_mean_squared_error: 1.7289 - val_loss: 4.3051 - val_y1_output_loss: 0.8587 - val_y2_output_loss: 3.4965 - val_y1_output_root_mean_squared_error: 0.9296 - val_y2_output_root_mean_squared_error: 1.8550
# Epoch 94/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1556 - y1_output_loss: 0.8198 - y2_output_loss: 2.4576 - y1_output_root_mean_squared_error: 0.9064 - y2_output_root_mean_squared_error: 1.5277 - val_loss: 27.2211 - val_y1_output_loss: 4.0061 - val_y2_output_loss: 22.4265 - val_y1_output_root_mean_squared_error: 2.0213 - val_y2_output_root_mean_squared_error: 4.8099
# Epoch 95/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.4767 - y1_output_loss: 0.9176 - y2_output_loss: 2.5392 - y1_output_root_mean_squared_error: 0.9612 - y2_output_root_mean_squared_error: 1.5977 - val_loss: 3.6617 - val_y1_output_loss: 0.6261 - val_y2_output_loss: 3.0997 - val_y1_output_root_mean_squared_error: 0.7964 - val_y2_output_root_mean_squared_error: 1.7399
# Epoch 96/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6350 - y1_output_loss: 0.9089 - y2_output_loss: 2.7541 - y1_output_root_mean_squared_error: 0.9570 - y2_output_root_mean_squared_error: 1.6490 - val_loss: 8.4271 - val_y1_output_loss: 1.2597 - val_y2_output_loss: 7.4388 - val_y1_output_root_mean_squared_error: 1.1266 - val_y2_output_root_mean_squared_error: 2.6754
# Epoch 97/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.9280 - y1_output_loss: 0.7180 - y2_output_loss: 2.2291 - y1_output_root_mean_squared_error: 0.8400 - y2_output_root_mean_squared_error: 1.4908 - val_loss: 9.9145 - val_y1_output_loss: 3.0839 - val_y2_output_loss: 6.5837 - val_y1_output_root_mean_squared_error: 1.7858 - val_y2_output_root_mean_squared_error: 2.5933
# Epoch 98/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.1954 - y1_output_loss: 0.7950 - y2_output_loss: 2.3883 - y1_output_root_mean_squared_error: 0.8930 - y2_output_root_mean_squared_error: 1.5485 - val_loss: 5.1196 - val_y1_output_loss: 0.6117 - val_y2_output_loss: 4.6912 - val_y1_output_root_mean_squared_error: 0.7957 - val_y2_output_root_mean_squared_error: 2.1181
# Epoch 99/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.0512 - y1_output_loss: 0.7982 - y2_output_loss: 2.2463 - y1_output_root_mean_squared_error: 0.8904 - y2_output_root_mean_squared_error: 1.5028 - val_loss: 5.3107 - val_y1_output_loss: 1.5865 - val_y2_output_loss: 3.6360 - val_y1_output_root_mean_squared_error: 1.2736 - val_y2_output_root_mean_squared_error: 1.9206
# Epoch 100/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8042 - y1_output_loss: 0.9656 - y2_output_loss: 2.8150 - y1_output_root_mean_squared_error: 0.9827 - y2_output_root_mean_squared_error: 1.6848 - val_loss: 3.6933 - val_y1_output_loss: 0.6957 - val_y2_output_loss: 3.0003 - val_y1_output_root_mean_squared_error: 0.8412 - val_y2_output_root_mean_squared_error: 1.7279
# Epoch 101/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.7064 - y1_output_loss: 0.6619 - y2_output_loss: 2.1281 - y1_output_root_mean_squared_error: 0.8138 - y2_output_root_mean_squared_error: 1.4297 - val_loss: 39.2967 - val_y1_output_loss: 8.6085 - val_y2_output_loss: 30.2148 - val_y1_output_root_mean_squared_error: 2.9843 - val_y2_output_root_mean_squared_error: 5.5128
# Epoch 102/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.3590 - y1_output_loss: 0.8783 - y2_output_loss: 2.5310 - y1_output_root_mean_squared_error: 0.9205 - y2_output_root_mean_squared_error: 1.5848 - val_loss: 8.2119 - val_y1_output_loss: 3.1008 - val_y2_output_loss: 4.9934 - val_y1_output_root_mean_squared_error: 1.7909 - val_y2_output_root_mean_squared_error: 2.2371
# Epoch 103/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.7675 - y1_output_loss: 0.9346 - y2_output_loss: 2.8143 - y1_output_root_mean_squared_error: 0.9691 - y2_output_root_mean_squared_error: 1.6818 - val_loss: 3.7476 - val_y1_output_loss: 0.6963 - val_y2_output_loss: 3.1185 - val_y1_output_root_mean_squared_error: 0.8425 - val_y2_output_root_mean_squared_error: 1.7429
# Epoch 104/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.7084 - y1_output_loss: 0.7005 - y2_output_loss: 2.0358 - y1_output_root_mean_squared_error: 0.8367 - y2_output_root_mean_squared_error: 1.4172 - val_loss: 4.2516 - val_y1_output_loss: 0.9872 - val_y2_output_loss: 3.2524 - val_y1_output_root_mean_squared_error: 1.0091 - val_y2_output_root_mean_squared_error: 1.7982
# Epoch 105/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.1199 - y1_output_loss: 0.7802 - y2_output_loss: 2.3166 - y1_output_root_mean_squared_error: 0.8870 - y2_output_root_mean_squared_error: 1.5275 - val_loss: 3.3826 - val_y1_output_loss: 0.5451 - val_y2_output_loss: 2.8705 - val_y1_output_root_mean_squared_error: 0.7391 - val_y2_output_root_mean_squared_error: 1.6842
# Epoch 106/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.6675 - y1_output_loss: 0.5609 - y2_output_loss: 2.1029 - y1_output_root_mean_squared_error: 0.7508 - y2_output_root_mean_squared_error: 1.4504 - val_loss: 3.5270 - val_y1_output_loss: 0.4880 - val_y2_output_loss: 3.1444 - val_y1_output_root_mean_squared_error: 0.7073 - val_y2_output_root_mean_squared_error: 1.7398
# Epoch 107/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.7222 - y1_output_loss: 0.6623 - y2_output_loss: 2.0422 - y1_output_root_mean_squared_error: 0.8165 - y2_output_root_mean_squared_error: 1.4337 - val_loss: 3.8015 - val_y1_output_loss: 0.4978 - val_y2_output_loss: 3.4623 - val_y1_output_root_mean_squared_error: 0.7137 - val_y2_output_root_mean_squared_error: 1.8144
# Epoch 108/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.7541 - y1_output_loss: 0.6073 - y2_output_loss: 2.1376 - y1_output_root_mean_squared_error: 0.7753 - y2_output_root_mean_squared_error: 1.4673 - val_loss: 3.6570 - val_y1_output_loss: 0.7685 - val_y2_output_loss: 2.9632 - val_y1_output_root_mean_squared_error: 0.8916 - val_y2_output_root_mean_squared_error: 1.6918
# Epoch 109/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3821 - y1_output_loss: 0.7730 - y2_output_loss: 2.5791 - y1_output_root_mean_squared_error: 0.8828 - y2_output_root_mean_squared_error: 1.6133 - val_loss: 3.5501 - val_y1_output_loss: 0.6012 - val_y2_output_loss: 3.0117 - val_y1_output_root_mean_squared_error: 0.7879 - val_y2_output_root_mean_squared_error: 1.7116
# Epoch 110/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7100 - y1_output_loss: 0.6715 - y2_output_loss: 2.1020 - y1_output_root_mean_squared_error: 0.8205 - y2_output_root_mean_squared_error: 1.4271 - val_loss: 18.4345 - val_y1_output_loss: 2.7556 - val_y2_output_loss: 16.2171 - val_y1_output_root_mean_squared_error: 1.6692 - val_y2_output_root_mean_squared_error: 3.9558
# Epoch 111/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3652 - y1_output_loss: 0.7905 - y2_output_loss: 2.5766 - y1_output_root_mean_squared_error: 0.8853 - y2_output_root_mean_squared_error: 1.6067 - val_loss: 5.3423 - val_y1_output_loss: 1.1437 - val_y2_output_loss: 4.5256 - val_y1_output_root_mean_squared_error: 1.0697 - val_y2_output_root_mean_squared_error: 2.0489
# Epoch 112/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8757 - y1_output_loss: 0.5938 - y2_output_loss: 2.2571 - y1_output_root_mean_squared_error: 0.7741 - y2_output_root_mean_squared_error: 1.5088 - val_loss: 3.5163 - val_y1_output_loss: 0.8288 - val_y2_output_loss: 2.7065 - val_y1_output_root_mean_squared_error: 0.9270 - val_y2_output_root_mean_squared_error: 1.6300
# Epoch 113/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.6964 - y1_output_loss: 0.6296 - y2_output_loss: 2.0604 - y1_output_root_mean_squared_error: 0.7962 - y2_output_root_mean_squared_error: 1.4361 - val_loss: 5.6359 - val_y1_output_loss: 1.2336 - val_y2_output_loss: 4.2942 - val_y1_output_root_mean_squared_error: 1.1238 - val_y2_output_root_mean_squared_error: 2.0912
# Epoch 114/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.7227 - y1_output_loss: 0.6750 - y2_output_loss: 2.0407 - y1_output_root_mean_squared_error: 0.8222 - y2_output_root_mean_squared_error: 1.4307 - val_loss: 9.9505 - val_y1_output_loss: 1.4139 - val_y2_output_loss: 8.7604 - val_y1_output_root_mean_squared_error: 1.2075 - val_y2_output_root_mean_squared_error: 2.9142
# Epoch 115/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4752 - y1_output_loss: 0.7933 - y2_output_loss: 2.6539 - y1_output_root_mean_squared_error: 0.8944 - y2_output_root_mean_squared_error: 1.6356 - val_loss: 3.1543 - val_y1_output_loss: 0.5909 - val_y2_output_loss: 2.5999 - val_y1_output_root_mean_squared_error: 0.7775 - val_y2_output_root_mean_squared_error: 1.5968
# Epoch 116/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.4032 - y1_output_loss: 0.5957 - y2_output_loss: 1.7924 - y1_output_root_mean_squared_error: 0.7752 - y2_output_root_mean_squared_error: 1.3425 - val_loss: 5.1939 - val_y1_output_loss: 1.5151 - val_y2_output_loss: 3.6069 - val_y1_output_root_mean_squared_error: 1.2378 - val_y2_output_root_mean_squared_error: 1.9136
# Epoch 117/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.6229 - y1_output_loss: 0.7581 - y2_output_loss: 1.8638 - y1_output_root_mean_squared_error: 0.8716 - y2_output_root_mean_squared_error: 1.3650 - val_loss: 3.6729 - val_y1_output_loss: 0.4625 - val_y2_output_loss: 3.1639 - val_y1_output_root_mean_squared_error: 0.6896 - val_y2_output_root_mean_squared_error: 1.7881
# Epoch 118/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.4502 - y1_output_loss: 0.5657 - y2_output_loss: 1.9432 - y1_output_root_mean_squared_error: 0.7529 - y2_output_root_mean_squared_error: 1.3723 - val_loss: 12.1500 - val_y1_output_loss: 1.0934 - val_y2_output_loss: 11.3554 - val_y1_output_root_mean_squared_error: 1.0583 - val_y2_output_root_mean_squared_error: 3.3212
# Epoch 119/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.3080 - y1_output_loss: 0.8117 - y2_output_loss: 2.4969 - y1_output_root_mean_squared_error: 0.9043 - y2_output_root_mean_squared_error: 1.5781 - val_loss: 7.0946 - val_y1_output_loss: 1.3583 - val_y2_output_loss: 5.5477 - val_y1_output_root_mean_squared_error: 1.1705 - val_y2_output_root_mean_squared_error: 2.3926
# Epoch 120/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.6282 - y1_output_loss: 0.6417 - y2_output_loss: 2.0035 - y1_output_root_mean_squared_error: 0.7990 - y2_output_root_mean_squared_error: 1.4106 - val_loss: 3.8264 - val_y1_output_loss: 0.5155 - val_y2_output_loss: 3.2916 - val_y1_output_root_mean_squared_error: 0.7189 - val_y2_output_root_mean_squared_error: 1.8192
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4308 - y1_output_loss: 0.1445 - y2_output_loss: 0.2829 - y1_output_root_mean_squared_error: 0.3814 - y2_output_root_mean_squared_error: 0.5342 - val_loss: 0.9290 - val_y1_output_loss: 0.2029 - val_y2_output_loss: 0.7158 - val_y1_output_root_mean_squared_error: 0.4543 - val_y2_output_root_mean_squared_error: 0.8500
# Epoch 462/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3590 - y1_output_loss: 0.1320 - y2_output_loss: 0.2240 - y1_output_root_mean_squared_error: 0.3648 - y2_output_root_mean_squared_error: 0.4753 - val_loss: 0.8816 - val_y1_output_loss: 0.1550 - val_y2_output_loss: 0.7215 - val_y1_output_root_mean_squared_error: 0.3988 - val_y2_output_root_mean_squared_error: 0.8501
# Epoch 463/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3975 - y1_output_loss: 0.1316 - y2_output_loss: 0.2660 - y1_output_root_mean_squared_error: 0.3611 - y2_output_root_mean_squared_error: 0.5168 - val_loss: 1.1394 - val_y1_output_loss: 0.2111 - val_y2_output_loss: 0.9238 - val_y1_output_root_mean_squared_error: 0.4633 - val_y2_output_root_mean_squared_error: 0.9616
# Epoch 464/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4323 - y1_output_loss: 0.1388 - y2_output_loss: 0.2906 - y1_output_root_mean_squared_error: 0.3739 - y2_output_root_mean_squared_error: 0.5408 - val_loss: 0.8921 - val_y1_output_loss: 0.1671 - val_y2_output_loss: 0.7157 - val_y1_output_root_mean_squared_error: 0.4119 - val_y2_output_root_mean_squared_error: 0.8499
# Epoch 465/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4952 - y1_output_loss: 0.1646 - y2_output_loss: 0.3454 - y1_output_root_mean_squared_error: 0.4013 - y2_output_root_mean_squared_error: 0.5781 - val_loss: 3.6407 - val_y1_output_loss: 1.2134 - val_y2_output_loss: 2.4716 - val_y1_output_root_mean_squared_error: 1.1008 - val_y2_output_root_mean_squared_error: 1.5585
# Epoch 466/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5207 - y1_output_loss: 0.1775 - y2_output_loss: 0.3487 - y1_output_root_mean_squared_error: 0.4183 - y2_output_root_mean_squared_error: 0.5880 - val_loss: 2.6890 - val_y1_output_loss: 0.4804 - val_y2_output_loss: 2.1561 - val_y1_output_root_mean_squared_error: 0.7035 - val_y2_output_root_mean_squared_error: 1.4812
# Epoch 467/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4389 - y1_output_loss: 0.1342 - y2_output_loss: 0.3032 - y1_output_root_mean_squared_error: 0.3673 - y2_output_root_mean_squared_error: 0.5513 - val_loss: 1.7330 - val_y1_output_loss: 0.2775 - val_y2_output_loss: 1.4068 - val_y1_output_root_mean_squared_error: 0.5323 - val_y2_output_root_mean_squared_error: 1.2040
# Epoch 468/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4672 - y1_output_loss: 0.1502 - y2_output_loss: 0.3129 - y1_output_root_mean_squared_error: 0.3891 - y2_output_root_mean_squared_error: 0.5619 - val_loss: 0.8998 - val_y1_output_loss: 0.1751 - val_y2_output_loss: 0.7140 - val_y1_output_root_mean_squared_error: 0.4228 - val_y2_output_root_mean_squared_error: 0.8492
# Epoch 469/500
# 614/614 [==============================] - 0s 120us/sample - loss: 0.3274 - y1_output_loss: 0.1157 - y2_output_loss: 0.2131 - y1_output_root_mean_squared_error: 0.3370 - y2_output_root_mean_squared_error: 0.4625 - val_loss: 1.1399 - val_y1_output_loss: 0.1903 - val_y2_output_loss: 0.9459 - val_y1_output_root_mean_squared_error: 0.4405 - val_y2_output_root_mean_squared_error: 0.9726
# Epoch 470/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4230 - y1_output_loss: 0.1279 - y2_output_loss: 0.2937 - y1_output_root_mean_squared_error: 0.3564 - y2_output_root_mean_squared_error: 0.5440 - val_loss: 1.1465 - val_y1_output_loss: 0.2251 - val_y2_output_loss: 0.9048 - val_y1_output_root_mean_squared_error: 0.4754 - val_y2_output_root_mean_squared_error: 0.9594
# Epoch 471/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3939 - y1_output_loss: 0.1240 - y2_output_loss: 0.2679 - y1_output_root_mean_squared_error: 0.3525 - y2_output_root_mean_squared_error: 0.5193 - val_loss: 0.8886 - val_y1_output_loss: 0.1660 - val_y2_output_loss: 0.7190 - val_y1_output_root_mean_squared_error: 0.4128 - val_y2_output_root_mean_squared_error: 0.8475
# Epoch 472/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4698 - y1_output_loss: 0.1557 - y2_output_loss: 0.3132 - y1_output_root_mean_squared_error: 0.3934 - y2_output_root_mean_squared_error: 0.5613 - val_loss: 1.1517 - val_y1_output_loss: 0.2342 - val_y2_output_loss: 0.9160 - val_y1_output_root_mean_squared_error: 0.4861 - val_y2_output_root_mean_squared_error: 0.9567
# Epoch 473/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4711 - y1_output_loss: 0.1764 - y2_output_loss: 0.2905 - y1_output_root_mean_squared_error: 0.4218 - y2_output_root_mean_squared_error: 0.5415 - val_loss: 0.9145 - val_y1_output_loss: 0.1722 - val_y2_output_loss: 0.7302 - val_y1_output_root_mean_squared_error: 0.4205 - val_y2_output_root_mean_squared_error: 0.8589
# Epoch 474/500
# 614/614 [==============================] - 0s 121us/sample - loss: 0.4125 - y1_output_loss: 0.1314 - y2_output_loss: 0.2818 - y1_output_root_mean_squared_error: 0.3589 - y2_output_root_mean_squared_error: 0.5327 - val_loss: 1.0491 - val_y1_output_loss: 0.1914 - val_y2_output_loss: 0.8420 - val_y1_output_root_mean_squared_error: 0.4425 - val_y2_output_root_mean_squared_error: 0.9238
# Epoch 475/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.6918 - y1_output_loss: 0.2095 - y2_output_loss: 0.4793 - y1_output_root_mean_squared_error: 0.4593 - y2_output_root_mean_squared_error: 0.6934 - val_loss: 0.9679 - val_y1_output_loss: 0.2192 - val_y2_output_loss: 0.7327 - val_y1_output_root_mean_squared_error: 0.4727 - val_y2_output_root_mean_squared_error: 0.8628
# Epoch 476/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3932 - y1_output_loss: 0.1302 - y2_output_loss: 0.2612 - y1_output_root_mean_squared_error: 0.3610 - y2_output_root_mean_squared_error: 0.5127 - val_loss: 1.2166 - val_y1_output_loss: 0.2314 - val_y2_output_loss: 0.9773 - val_y1_output_root_mean_squared_error: 0.4848 - val_y2_output_root_mean_squared_error: 0.9907
# Epoch 477/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4108 - y1_output_loss: 0.1344 - y2_output_loss: 0.2742 - y1_output_root_mean_squared_error: 0.3664 - y2_output_root_mean_squared_error: 0.5258 - val_loss: 1.1112 - val_y1_output_loss: 0.2676 - val_y2_output_loss: 0.8339 - val_y1_output_root_mean_squared_error: 0.5261 - val_y2_output_root_mean_squared_error: 0.9134
# Epoch 478/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3765 - y1_output_loss: 0.1395 - y2_output_loss: 0.2340 - y1_output_root_mean_squared_error: 0.3748 - y2_output_root_mean_squared_error: 0.4858 - val_loss: 0.8807 - val_y1_output_loss: 0.1663 - val_y2_output_loss: 0.7053 - val_y1_output_root_mean_squared_error: 0.4108 - val_y2_output_root_mean_squared_error: 0.8438
# Epoch 479/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4935 - y1_output_loss: 0.1510 - y2_output_loss: 0.3421 - y1_output_root_mean_squared_error: 0.3887 - y2_output_root_mean_squared_error: 0.5851 - val_loss: 1.1505 - val_y1_output_loss: 0.1892 - val_y2_output_loss: 0.9671 - val_y1_output_root_mean_squared_error: 0.4382 - val_y2_output_root_mean_squared_error: 0.9790
# Epoch 480/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3668 - y1_output_loss: 0.1303 - y2_output_loss: 0.2347 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.4851 - val_loss: 0.9522 - val_y1_output_loss: 0.1638 - val_y2_output_loss: 0.7736 - val_y1_output_root_mean_squared_error: 0.4079 - val_y2_output_root_mean_squared_error: 0.8865
# Epoch 481/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3826 - y1_output_loss: 0.1331 - y2_output_loss: 0.2505 - y1_output_root_mean_squared_error: 0.3660 - y2_output_root_mean_squared_error: 0.4986 - val_loss: 1.5732 - val_y1_output_loss: 0.1682 - val_y2_output_loss: 1.4161 - val_y1_output_root_mean_squared_error: 0.4093 - val_y2_output_root_mean_squared_error: 1.1856
# Epoch 482/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4373 - y1_output_loss: 0.1464 - y2_output_loss: 0.2893 - y1_output_root_mean_squared_error: 0.3842 - y2_output_root_mean_squared_error: 0.5382 - val_loss: 1.0231 - val_y1_output_loss: 0.1625 - val_y2_output_loss: 0.8742 - val_y1_output_root_mean_squared_error: 0.4041 - val_y2_output_root_mean_squared_error: 0.9273
# Epoch 483/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3884 - y1_output_loss: 0.1310 - y2_output_loss: 0.2544 - y1_output_root_mean_squared_error: 0.3631 - y2_output_root_mean_squared_error: 0.5065 - val_loss: 0.9092 - val_y1_output_loss: 0.1578 - val_y2_output_loss: 0.7457 - val_y1_output_root_mean_squared_error: 0.4020 - val_y2_output_root_mean_squared_error: 0.8647
# Epoch 484/500
# 614/614 [==============================] - 0s 122us/sample - loss: 0.4029 - y1_output_loss: 0.1486 - y2_output_loss: 0.2561 - y1_output_root_mean_squared_error: 0.3828 - y2_output_root_mean_squared_error: 0.5063 - val_loss: 1.7822 - val_y1_output_loss: 0.4562 - val_y2_output_loss: 1.2973 - val_y1_output_root_mean_squared_error: 0.6751 - val_y2_output_root_mean_squared_error: 1.1517
# Epoch 485/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3654 - y1_output_loss: 0.1314 - y2_output_loss: 0.2421 - y1_output_root_mean_squared_error: 0.3608 - y2_output_root_mean_squared_error: 0.4850 - val_loss: 1.5571 - val_y1_output_loss: 0.1730 - val_y2_output_loss: 1.4052 - val_y1_output_root_mean_squared_error: 0.4206 - val_y2_output_root_mean_squared_error: 1.1748
# Epoch 486/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4000 - y1_output_loss: 0.1302 - y2_output_loss: 0.2673 - y1_output_root_mean_squared_error: 0.3623 - y2_output_root_mean_squared_error: 0.5184 - val_loss: 1.1208 - val_y1_output_loss: 0.1474 - val_y2_output_loss: 0.9919 - val_y1_output_root_mean_squared_error: 0.3861 - val_y2_output_root_mean_squared_error: 0.9857
# Epoch 487/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.8123 - y1_output_loss: 0.2371 - y2_output_loss: 0.5678 - y1_output_root_mean_squared_error: 0.4891 - y2_output_root_mean_squared_error: 0.7570 - val_loss: 0.8982 - val_y1_output_loss: 0.1599 - val_y2_output_loss: 0.7340 - val_y1_output_root_mean_squared_error: 0.4034 - val_y2_output_root_mean_squared_error: 0.8575
# Epoch 488/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4717 - y1_output_loss: 0.1540 - y2_output_loss: 0.3158 - y1_output_root_mean_squared_error: 0.3938 - y2_output_root_mean_squared_error: 0.5627 - val_loss: 0.9566 - val_y1_output_loss: 0.1663 - val_y2_output_loss: 0.7975 - val_y1_output_root_mean_squared_error: 0.4111 - val_y2_output_root_mean_squared_error: 0.8875
# Epoch 489/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3563 - y1_output_loss: 0.1280 - y2_output_loss: 0.2272 - y1_output_root_mean_squared_error: 0.3584 - y2_output_root_mean_squared_error: 0.4774 - val_loss: 0.9620 - val_y1_output_loss: 0.1916 - val_y2_output_loss: 0.7578 - val_y1_output_root_mean_squared_error: 0.4388 - val_y2_output_root_mean_squared_error: 0.8772
# Epoch 490/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.5210 - y1_output_loss: 0.1523 - y2_output_loss: 0.3672 - y1_output_root_mean_squared_error: 0.3916 - y2_output_root_mean_squared_error: 0.6063 - val_loss: 0.9106 - val_y1_output_loss: 0.1545 - val_y2_output_loss: 0.7488 - val_y1_output_root_mean_squared_error: 0.3953 - val_y2_output_root_mean_squared_error: 0.8685
# Epoch 491/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3952 - y1_output_loss: 0.1310 - y2_output_loss: 0.2638 - y1_output_root_mean_squared_error: 0.3617 - y2_output_root_mean_squared_error: 0.5141 - val_loss: 0.9864 - val_y1_output_loss: 0.1630 - val_y2_output_loss: 0.8087 - val_y1_output_root_mean_squared_error: 0.4085 - val_y2_output_root_mean_squared_error: 0.9053
# Epoch 492/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3332 - y1_output_loss: 0.1162 - y2_output_loss: 0.2160 - y1_output_root_mean_squared_error: 0.3418 - y2_output_root_mean_squared_error: 0.4651 - val_loss: 0.9616 - val_y1_output_loss: 0.1626 - val_y2_output_loss: 0.7978 - val_y1_output_root_mean_squared_error: 0.4077 - val_y2_output_root_mean_squared_error: 0.8919
# Epoch 493/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3626 - y1_output_loss: 0.1206 - y2_output_loss: 0.2457 - y1_output_root_mean_squared_error: 0.3465 - y2_output_root_mean_squared_error: 0.4925 - val_loss: 2.0771 - val_y1_output_loss: 0.5238 - val_y2_output_loss: 1.5657 - val_y1_output_root_mean_squared_error: 0.7123 - val_y2_output_root_mean_squared_error: 1.2529
# Epoch 494/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3827 - y1_output_loss: 0.1451 - y2_output_loss: 0.2489 - y1_output_root_mean_squared_error: 0.3636 - y2_output_root_mean_squared_error: 0.5005 - val_loss: 0.9341 - val_y1_output_loss: 0.2592 - val_y2_output_loss: 0.6771 - val_y1_output_root_mean_squared_error: 0.5011 - val_y2_output_root_mean_squared_error: 0.8264
# Epoch 495/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4028 - y1_output_loss: 0.1379 - y2_output_loss: 0.2648 - y1_output_root_mean_squared_error: 0.3710 - y2_output_root_mean_squared_error: 0.5149 - val_loss: 0.9091 - val_y1_output_loss: 0.1740 - val_y2_output_loss: 0.7381 - val_y1_output_root_mean_squared_error: 0.4215 - val_y2_output_root_mean_squared_error: 0.8552
# Epoch 496/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4457 - y1_output_loss: 0.1441 - y2_output_loss: 0.3073 - y1_output_root_mean_squared_error: 0.3795 - y2_output_root_mean_squared_error: 0.5492 - val_loss: 0.9553 - val_y1_output_loss: 0.2383 - val_y2_output_loss: 0.7122 - val_y1_output_root_mean_squared_error: 0.4883 - val_y2_output_root_mean_squared_error: 0.8467
# Epoch 497/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3752 - y1_output_loss: 0.1311 - y2_output_loss: 0.2480 - y1_output_root_mean_squared_error: 0.3581 - y2_output_root_mean_squared_error: 0.4970 - val_loss: 1.5032 - val_y1_output_loss: 0.3523 - val_y2_output_loss: 1.1107 - val_y1_output_root_mean_squared_error: 0.5998 - val_y2_output_root_mean_squared_error: 1.0693
# Epoch 498/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4318 - y1_output_loss: 0.1495 - y2_output_loss: 0.2792 - y1_output_root_mean_squared_error: 0.3879 - y2_output_root_mean_squared_error: 0.5305 - val_loss: 0.8739 - val_y1_output_loss: 0.1674 - val_y2_output_loss: 0.7043 - val_y1_output_root_mean_squared_error: 0.4138 - val_y2_output_root_mean_squared_error: 0.8382
# Epoch 499/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3143 - y1_output_loss: 0.1183 - y2_output_loss: 0.2021 - y1_output_root_mean_squared_error: 0.3401 - y2_output_root_mean_squared_error: 0.4457 - val_loss: 1.4658 - val_y1_output_loss: 0.3205 - val_y2_output_loss: 1.1261 - val_y1_output_root_mean_squared_error: 0.5700 - val_y2_output_root_mean_squared_error: 1.0682
# Epoch 500/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3865 - y1_output_loss: 0.1224 - y2_output_loss: 0.2625 - y1_output_root_mean_squared_error: 0.3495 - y2_output_root_mean_squared_error: 0.5141 - val_loss: 1.3127 - val_y1_output_loss: 0.2898 - val_y2_output_loss: 1.0147 - val_y1_output_root_mean_squared_error: 0.5432 - val_y2_output_root_mean_squared_error: 1.0088

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 1.3127 - y1_output_loss: 0.2882 - y2_output_loss: 0.9993 - y1_output_root_mean_squared_error: 0.5432 - y2_output_root_mean_squared_error: 1.0088
# Loss = 1.312696688360982, Y1_loss = 0.2882162928581238, Y1_mse = 0.5432103276252747, Y2_loss = 0.999256432056427, Y2_mse = 1.0087710618972778

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
